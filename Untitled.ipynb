# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
y = train.Survived
train = train.drop(['Survived'],axis=1)
train.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
frames = [train,test]
df = pd.concat(frames, axis=0, join='outer', join_axes=None, ignore_index=True,
          keys=None, levels=None, names=None, verify_integrity=False,
          copy=True)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (1309, 11)

# %%
def get_titles():

    global df
    
    df['Title'] = df['Name'].map(lambda name:name.split(',')[1].split('.')[0].strip())
    Title_Dictionary = {
                        "Capt":       "Officer",
                        "Col":        "Officer",
                        "Major":      "Officer",
                        "Jonkheer":   "Royalty",
                        "Don":        "Royalty",
                        "Sir" :       "Royalty",
                        "Dr":         "Officer",
                        "Rev":        "Officer",
                        "the Countess":"Royalty",
                        "Dona":       "Royalty",
                        "Mme":        "Mrs",
                        "Mlle":       "Miss",
                        "Ms":         "Mrs",
                        "Mr" :        "Mr",
                        "Mrs" :       "Mrs",
                        "Miss" :      "Miss",
                        "Master" :    "Master",
                        "Lady" :      "Royalty"

                        }
    df['Title'] = df.Title.map(Title_Dictionary)

# %%
get_titles()

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked Title
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S    Mr
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C   Mrs
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3  female  35.0      1      0            113803  53.1000  C123        S   Mrs
# 4    male  35.0      0      0            373450   8.0500   NaN        S    Mr

# %%
pd.get_dummies(df['Sex']).head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
df = pd.concat([df,pd.get_dummies(df['Sex'])],axis=1)
df.drop(['Sex'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked Title  female  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S    Mr       0
# 1  38.0      1      0          PC 17599  71.2833   C85        C   Mrs       1
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Miss       1
# 3  35.0      1      0            113803  53.1000  C123        S   Mrs       1
# 4  35.0      0      0            373450   8.0500   NaN        S    Mr       0
#
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# ...

# %%
allTitles = list(set(df['Title']))
allTitles
# Out:
# ['Miss', 'Mrs', 'Master', 'Royalty', 'Mr', 'Officer']

# %%
x=(df[df['Title']==allTitles[2]]['Age']).median(axis=None,skipna=True)
x
# Out:
# 4.0

# %%
plt.scatter(df[df['Title']==allTitles[2]].PassengerId,df[df['Title']==allTitles[2]].Age)

# %%
for i in allTitles:
    medianAge=(df[df['Title']==i]['Age']).median(axis=None,skipna=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-182-e6db3cc25b70> in <module>()
#       1 for i in allTitles:
#       2     medianAge=(df[df['Title']==i]['Age']).median(axis=None,skipna=True)
# ----> 3     df.loc[(df['Title']==i&df.Age.isnull),'Age'] = medianAge
#
# TypeError: unsupported operand type(s) for &: 'str' and 'method'

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# Title             0
# female            0
# male              0
# dtype: int64

# %%
df[df['Title']==i]['Age'].isnull().sum()
# Out:
# 50

# %%
medianAge = [df[df['Title']==i]['Age'].median(axis=None,skipna=True) for i in allTitles]

# %%
print(medianAge)
print(allTitles)
# Out:
# [22.0, 35.0, 4.0, 39.5, 29.0, 49.5]
# ['Miss', 'Mrs', 'Master', 'Royalty', 'Mr', 'Officer']

# %%
fillAge = dict(zip(allTitles,medianAge))
